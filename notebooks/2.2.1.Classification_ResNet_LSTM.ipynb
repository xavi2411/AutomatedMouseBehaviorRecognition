# %% [markdown]
# # Frame Classification using ResNet + LSTM
#
# - Create the LSTM model
# - Cross validate the model using different hyperparameters configurations
# - Train the best model
# - Evaluate the best model within the testing videos

# %%
from utils import *

# %% [markdown]
# ## Create the hyperparameters search space

# %%
config = {
    'abs_path': '/home/xavi/Documents/BecaMaster+/TFM_CODE/',
    'sequence_length': [300, 600, 1650],
    'backbone': 'resnet',
    'layers': 'lstm',
    'dropout_rate': 0.5,
    'num_layers': [1, 2, 3],
    'num_units': [64, 128, 256],
    'loss': 'binary_crossentropy',
    'optimizer': 'adam',
    'learning_rate': 0.001,
    'epochs': 50,
    'batch_size': [8, 16, 32],
    'es_monitor': 'val_prc',
    'es_mode': 'max',
    'es_patience': 5,
}

# %% [markdown]
# ## Perform the Grid Search

# %%
best_config = grid_search(config)
# Out:
# == Status ==<br>Current time: 2022-05-12 20:08:57 (running for 00:00:00.07)<br>Memory usage on this node: 11.8/31.3 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/12 CPUs, 0/1 GPUs, 0.0/12.53 GiB heap, 0.0/6.26 GiB objects (0.0/1.0 accelerator_type:G)<br>Current best trial: f2154_00006 with accuracy=0.9064772725105287 and parameters={'abs_path': '/home/xavi/Documents/BecaMaster+/TFM_CODE/', 'sequence_length': 300, 'backbone': 'resnet', 'layers': 'lstm', 'dropout_rate': 0.5, 'num_layers': 3, 'num_units': 64, 'loss': 'binary_crossentropy', 'optimizer': 'adam', 'learning_rate': 0.001, 'epochs': 50, 'batch_size': 8, 'es_monitor': 'val_prc', 'es_mode': 'max', 'es_patience': 5}<br>Result logdir: /home/xavi/ray_results/tune_train_2022-05-09_18-41-59<br>Number of trials: 81/81 (81 TERMINATED)<br><br>
# 2022-05-12 20:08:57,905	INFO tune.py:636 -- Total run time: 0.27 seconds (0.00 seconds for the tuning loop).

# %% [markdown]
# ## Final model Training & Evaluation

# %%
metrics = train_test_model(best_config)
# Out:
# Running experiment for Grooming
# Results:
# 	Loss: 0.2398749589920044
# 	TruePositives: 2182.0
# 	FalsePositives: 3110.0
# 	TrueNegatives: 27583.0
# 	FalseNegatives: 125.0
# 	Accuracy: 0.9019696712493896
# 	Precision: 0.41232049465179443
# 	Recall: 0.9458170533180237
# 	PRC: 0.6787223815917969
# Running experiment for Mid Rearing
# Results:
# 	Loss: 0.2583831548690796
# 	TruePositives: 2854.0
# 	FalsePositives: 2657.0
# 	TrueNegatives: 26762.0
# 	FalseNegatives: 727.0
# 	Accuracy: 0.897454559803009
# 	Precision: 0.5178733468055725
# 	Recall: 0.796984076499939
# 	PRC: 0.701962947845459
# Running experiment for Wall Rearing
# Results:
# 	Loss: 0.23853152990341187
# 	TruePositives: 3530.0
# 	FalsePositives: 1729.0
# 	TrueNegatives: 26773.0
# 	FalseNegatives: 968.0
# 	Accuracy: 0.9182727336883545
# 	Precision: 0.6712302565574646
# 	Recall: 0.7847932577133179
# 	PRC: 0.7924763560295105
