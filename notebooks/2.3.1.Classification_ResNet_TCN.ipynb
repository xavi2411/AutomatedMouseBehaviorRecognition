# %% [markdown]
# # Frame Classification using ResNet + LSTM
#
# - Create the LSTM model
# - Cross validate the model using different hyperparameters configurations
# - Train the best model
# - Evaluate the best model within the testing videos

# %%
from utils import *

# %% [markdown]
# ## Create the hyperparameters search space

# %%
config = {
    'abs_path': '/home/xavi/Documents/BecaMaster+/TFM_CODE/',
    'sequence_length': [300, 600, 1650],
    'backbone': 'resnet',
    'layers': 'tcn',
    'dropout_rate': 0.5,
    'num_layers': [1, 2, 3],
    'num_units': [256, 512, 1024],
    'kernel_size': [3, 5],
    'norm': 'batch',
    'loss': 'binary_crossentropy',
    'optimizer': 'adam',
    'learning_rate': 0.001,
    'epochs': 50,
    'batch_size': [8, 16, 32],
    'es_monitor': 'val_prc',
    'es_mode': 'max',
    'es_patience': 5,
}

# %% [markdown]
# ## Perform the Grid Search

# %%
best_config = grid_search(config)
# Out:
# == Status ==<br>Current time: 2022-05-17 16:46:06 (running for 00:00:00.12)<br>Memory usage on this node: 10.1/31.3 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/12 CPUs, 0/1 GPUs, 0.0/13.53 GiB heap, 0.0/6.77 GiB objects (0.0/1.0 accelerator_type:G)<br>Current best trial: 250fd_00002 with accuracy=0.9168139729234909 and parameters={'abs_path': '/home/xavi/Documents/BecaMaster+/TFM_CODE/', 'sequence_length': 300, 'backbone': 'resnet', 'layers': 'tcn', 'dropout_rate': 0.5, 'num_layers': 1, 'num_units': 256, 'kernel_size': 3, 'norm': 'batch', 'loss': 'binary_crossentropy', 'optimizer': 'adam', 'learning_rate': 0.001, 'epochs': 50, 'batch_size': 32, 'es_monitor': 'val_prc', 'es_mode': 'max', 'es_patience': 5}<br>Result logdir: /home/xavi/ray_results/tune_train_2022-05-14_12-32-24<br>Number of trials: 162/162 (15 ERROR, 147 TERMINATED)<br>Number of errored trials: 15<br><table>
# <thead>
# <tr><th>Trial name         </th><th style="text-align: right;">  # failures</th><th>error file                                                                                                                                                                              </th></tr>
# </thead>
# <tbody>
# <tr><td>tune_train_dbe3a6b0</td><td style="text-align: right;">           1</td><td>/home/xavi/ray_results/tune_train_2022-05-14_12-32-24/tune_train_dbe3a6b0_134_batch_size=32,kernel_size=3,num_layers=2,num_units=512,sequence_length=1650_2022-05-17_16-23-03/error.txt </td></tr>
# <tr><td>tune_train_dbe3a6b9</td><td style="text-align: right;">           1</td><td>/home/xavi/ray_results/tune_train_2022-05-14_12-32-24/tune_train_dbe3a6b9_155_batch_size=32,kernel_size=5,num_layers=2,num_units=1024,sequence_length=1650_2022-05-17_16-33-16/error.txt</td></tr>
# <tr><td>tune_train_dbe3a6bd</td><td style="text-align: right;">           1</td><td>/home/xavi/ray_results/tune_train_2022-05-14_12-32-24/tune_train_dbe3a6bd_161_batch_size=32,kernel_size=5,num_layers=3,num_units=1024,sequence_length=1650_2022-05-17_16-35-11/error.txt</td></tr>
# <tr><td>tune_train_dbe3a6b2</td><td style="text-align: right;">           1</td><td>/home/xavi/ray_results/tune_train_2022-05-14_12-32-24/tune_train_dbe3a6b2_140_batch_size=32,kernel_size=3,num_layers=3,num_units=512,sequence_length=1650_2022-05-17_16-30-04/error.txt </td></tr>
# <tr><td>tune_train_dbe3a6ba</td><td style="text-align: right;">           1</td><td>/home/xavi/ray_results/tune_train_2022-05-14_12-32-24/tune_train_dbe3a6ba_157_batch_size=16,kernel_size=3,num_layers=3,num_units=1024,sequence_length=1650_2022-05-17_16-33-42/error.txt</td></tr>
# <tr><td>tune_train_dbe3a6bc</td><td style="text-align: right;">           1</td><td>/home/xavi/ray_results/tune_train_2022-05-14_12-32-24/tune_train_dbe3a6bc_160_batch_size=16,kernel_size=5,num_layers=3,num_units=1024,sequence_length=1650_2022-05-17_16-34-44/error.txt</td></tr>
# <tr><td>tune_train_dbe3a6b1</td><td style="text-align: right;">           1</td><td>/home/xavi/ray_results/tune_train_2022-05-14_12-32-24/tune_train_dbe3a6b1_137_batch_size=32,kernel_size=5,num_layers=2,num_units=512,sequence_length=1650_2022-05-17_16-29-41/error.txt </td></tr>
# <tr><td>tune_train_dbe3a6af</td><td style="text-align: right;">           1</td><td>/home/xavi/ray_results/tune_train_2022-05-14_12-32-24/tune_train_dbe3a6af_107_batch_size=32,kernel_size=5,num_layers=3,num_units=1024,sequence_length=600_2022-05-17_16-23-02/error.txt </td></tr>
# <tr><td>tune_train_dbe3a6bb</td><td style="text-align: right;">           1</td><td>/home/xavi/ray_results/tune_train_2022-05-14_12-32-24/tune_train_dbe3a6bb_158_batch_size=32,kernel_size=3,num_layers=3,num_units=1024,sequence_length=1650_2022-05-17_16-34-08/error.txt</td></tr>
# <tr><td>tune_train_dbe3a6b4</td><td style="text-align: right;">           1</td><td>/home/xavi/ray_results/tune_train_2022-05-14_12-32-24/tune_train_dbe3a6b4_146_batch_size=32,kernel_size=3,num_layers=1,num_units=1024,sequence_length=1650_2022-05-17_16-31-03/error.txt</td></tr>
# <tr><td>tune_train_dbe3a6b8</td><td style="text-align: right;">           1</td><td>/home/xavi/ray_results/tune_train_2022-05-14_12-32-24/tune_train_dbe3a6b8_154_batch_size=16,kernel_size=5,num_layers=2,num_units=1024,sequence_length=1650_2022-05-17_16-32-51/error.txt</td></tr>
# <tr><td>tune_train_dbe3a6b5</td><td style="text-align: right;">           1</td><td>/home/xavi/ray_results/tune_train_2022-05-14_12-32-24/tune_train_dbe3a6b5_149_batch_size=32,kernel_size=5,num_layers=1,num_units=1024,sequence_length=1650_2022-05-17_16-31-39/error.txt</td></tr>
# <tr><td>tune_train_dbe3a6b3</td><td style="text-align: right;">           1</td><td>/home/xavi/ray_results/tune_train_2022-05-14_12-32-24/tune_train_dbe3a6b3_143_batch_size=32,kernel_size=5,num_layers=3,num_units=512,sequence_length=1650_2022-05-17_16-30-28/error.txt </td></tr>
# <tr><td>tune_train_dbe3a6b7</td><td style="text-align: right;">           1</td><td>/home/xavi/ray_results/tune_train_2022-05-14_12-32-24/tune_train_dbe3a6b7_152_batch_size=32,kernel_size=3,num_layers=2,num_units=1024,sequence_length=1650_2022-05-17_16-32-26/error.txt</td></tr>
# <tr><td>tune_train_dbe3a6b6</td><td style="text-align: right;">           1</td><td>/home/xavi/ray_results/tune_train_2022-05-14_12-32-24/tune_train_dbe3a6b6_151_batch_size=16,kernel_size=3,num_layers=2,num_units=1024,sequence_length=1650_2022-05-17_16-32-02/error.txt</td></tr>
# </tbody>
# </table><br>
# 2022-05-17 16:46:06,276	ERROR tune.py:632 -- Trials did not complete: [tune_train_dbe3a6b0, tune_train_dbe3a6b9, tune_train_dbe3a6bd, tune_train_dbe3a6b2, tune_train_dbe3a6ba, tune_train_dbe3a6bc, tune_train_dbe3a6b1, tune_train_dbe3a6af, tune_train_dbe3a6bb, tune_train_dbe3a6b4, tune_train_dbe3a6b8, tune_train_dbe3a6b5, tune_train_dbe3a6b3, tune_train_dbe3a6b7, tune_train_dbe3a6b6]
# 2022-05-17 16:46:06,277	INFO tune.py:636 -- Total run time: 0.40 seconds (0.00 seconds for the tuning loop).

# %% [markdown]
# ## Final model Training & Evaluation

# %%
metrics = train_test_model(best_config)
# Out:
# Running experiment for Grooming
# Results:
# 	Loss: 0.2514628767967224
# 	TruePositives: 1240.0
# 	FalsePositives: 580.0
# 	TrueNegatives: 30113.0
# 	FalseNegatives: 1067.0
# 	Accuracy: 0.9500908851623535
# 	Precision: 0.6813187003135681
# 	Recall: 0.5374945998191833
# 	PRC: 0.5888190269470215
# Running experiment for Mid Rearing
# Results:
# 	Loss: 1.1854009628295898
# 	TruePositives: 374.0
# 	FalsePositives: 527.0
# 	TrueNegatives: 28892.0
# 	FalseNegatives: 3207.0
# 	Accuracy: 0.886848509311676
# 	Precision: 0.4150943458080292
# 	Recall: 0.1044401004910469
# 	PRC: 0.2011682093143463
# Running experiment for Wall Rearing
# Results:
# 	Loss: 1.0694246292114258
# 	TruePositives: 2566.0
# 	FalsePositives: 3361.0
# 	TrueNegatives: 25141.0
# 	FalseNegatives: 1932.0
# 	Accuracy: 0.8396060466766357
# 	Precision: 0.4329340159893036
# 	Recall: 0.5704757571220398
# 	PRC: 0.41098058223724365
