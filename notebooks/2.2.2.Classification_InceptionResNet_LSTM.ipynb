# %% [markdown]
# # Frame Classification using InceptionResNet + LSTM
#
# - Create the LSTM model
# - Cross validate the model using different hyperparameters configurations
# - Train the best model
# - Evaluate the best model within the testing videos

# %%
from utils import *

# %% [markdown]
# ## Create the hyperparameters search space

# %%
config = {
    'abs_path': '/home/xavi/Documents/MasterDataScience/TFM/AutomatedMouseBehaviorRecognition',
    'sequence_length': [300, 600, 1650],
    'backbone': 'inception_resnet',
    'layers': 'lstm',
    'dropout_rate': 0.5,
    'num_layers': [1, 2, 3],
    'num_units': [64, 128, 256],
    'loss': 'binary_crossentropy',
    'optimizer': 'adam',
    'learning_rate': 0.001,
    'epochs': 50,
    'batch_size': [8, 16, 32],
    'es_monitor': 'val_prc',
    'es_mode': 'max',
    'es_patience': 5,
}

# %% [markdown]
# ## Perform the Grid Search

# %%
best_config = grid_search(config)
# Out:
# == Status ==<br>Current time: 2022-05-12 20:06:38 (running for 00:00:00.06)<br>Memory usage on this node: 11.9/31.3 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/12 CPUs, 0/1 GPUs, 0.0/9.68 GiB heap, 0.0/4.84 GiB objects (0.0/1.0 accelerator_type:G)<br>Current best trial: eb032_00031 with accuracy=0.9022390627198748 and parameters={'abs_path': '/home/xavi/Documents/BecaMaster+/TFM_CODE/', 'sequence_length': 600, 'backbone': 'inception_resnet', 'layers': 'lstm', 'dropout_rate': 0.5, 'num_layers': 2, 'num_units': 64, 'loss': 'binary_crossentropy', 'optimizer': 'adam', 'learning_rate': 0.001, 'epochs': 50, 'batch_size': 16, 'es_monitor': 'val_prc', 'es_mode': 'max', 'es_patience': 5}<br>Result logdir: /home/xavi/ray_results/tune_train_2022-05-10_09-15-06<br>Number of trials: 81/81 (81 TERMINATED)<br><br>
# 2022-05-12 20:06:38,620	INFO tune.py:636 -- Total run time: 0.27 seconds (0.00 seconds for the tuning loop).

# %% [markdown]
# ## Final model Training & Evaluation

# %%
metrics = train_test_model(best_config)
# Out:
# Running experiment for Grooming
# Results:
# 	Loss: 0.23226985335350037
# 	TruePositives: 2020.0
# 	FalsePositives: 2721.0
# 	TrueNegatives: 27972.0
# 	FalseNegatives: 287.0
# 	Accuracy: 0.9088484644889832
# 	Precision: 0.4260704517364502
# 	Recall: 0.8755959868431091
# 	PRC: 0.6897075176239014
# Running experiment for Mid Rearing
# Results:
# 	Loss: 0.24025049805641174
# 	TruePositives: 2680.0
# 	FalsePositives: 2328.0
# 	TrueNegatives: 27091.0
# 	FalseNegatives: 901.0
# 	Accuracy: 0.9021515250205994
# 	Precision: 0.5351437926292419
# 	Recall: 0.7483943104743958
# 	PRC: 0.6910058259963989
# Running experiment for Wall Rearing
# Results:
# 	Loss: 0.23586827516555786
# 	TruePositives: 3315.0
# 	FalsePositives: 1651.0
# 	TrueNegatives: 26851.0
# 	FalseNegatives: 1183.0
# 	Accuracy: 0.9141212105751038
# 	Precision: 0.6675392389297485
# 	Recall: 0.736994206905365
# 	PRC: 0.7700109481811523
